# %% [markdown]
# Create a dictionary for the building block
#
# Key(Modification)-Value(Molecular weight)
#
# Key (e.g. 100) -> 1 block, 0 O-acetylation, 0 N-deacetylation

# %%
blocks = {'100':1040, '110':1082, '101':998, '111':1040}
water = 18
alanine = 89
ala_bridge = 2*alanine - water

# %% [markdown]
# Create a dictionary for monomers
#
# Eliminate duplicate values

# %%
monomers = {}
for key, value in blocks.items():
  if value not in monomers.values():
    monomers[key] = value

print(monomers)
print(len(monomers))
# Out:
# {'100': 1040, '110': 1082, '101': 998}
# 3

# %% [markdown]
# Create a dictionary for dimers

# %%
raw_dimers = {}
for key1, value1 in monomers.items():
  for key2, value2 in blocks.items():
    new_key = str(int(key1)+int(key2))
    new_value = value1+value2-water
    raw_dimers[new_key] = new_value

print(raw_dimers)
print(len(raw_dimers))

dimers = {}
for key, value in raw_dimers.items():
  if value not in dimers.values():
    dimers[key] = value

print(dimers)
print(len(dimers))
# Out:
# {'200': 2062, '210': 2104, '201': 2020, '211': 2062, '220': 2146, '221': 2104, '202': 1978, '212': 2020}
# 8
# {'200': 2062, '210': 2104, '201': 2020, '220': 2146, '202': 1978}
# 5

# %% [markdown]
# Create a dictionary for trimers

# %%
raw_trimers = {}
for key1, value1 in dimers.items():
  for key2, value2 in blocks.items():
    new_key = str(int(key1)+int(key2))
    new_value = value1+value2-water
    raw_trimers[new_key] = new_value

print(raw_trimers)
print(len(raw_trimers))

trimers = {}
for key, value in raw_trimers.items():
  if value not in trimers.values():
    trimers[key] = value

print(trimers)
print(len(trimers))
# Out:
# {'300': 3084, '310': 3126, '301': 3042, '311': 3084, '320': 3168, '321': 3126, '302': 3000, '312': 3042, '330': 3210, '331': 3168, '303': 2958, '313': 3000}
# 12
# {'300': 3084, '310': 3126, '301': 3042, '320': 3168, '302': 3000, '330': 3210, '303': 2958}
# 7

# %% [markdown]
# Create a dictionary for tetramers

# %%
raw_tetramers = {}
for key1, value1 in trimers.items():
  for key2, value2 in blocks.items():
    new_key = str(int(key1)+int(key2))
    new_value = value1+value2-water
    raw_tetramers[new_key] = new_value

print(raw_tetramers)
print(len(raw_tetramers))

tetramers = {}
for key, value in raw_tetramers.items():
  if value not in tetramers.values():
    tetramers[key] = value

print(tetramers)
print(len(tetramers))
# Out:
# {'400': 4106, '410': 4148, '401': 4064, '411': 4106, '420': 4190, '421': 4148, '402': 4022, '412': 4064, '430': 4232, '431': 4190, '403': 3980, '413': 4022, '440': 4274, '441': 4232, '404': 3938, '414': 3980}
# 16
# {'400': 4106, '410': 4148, '401': 4064, '420': 4190, '402': 4022, '430': 4232, '403': 3980, '440': 4274, '404': 3938}
# 9

# %% [markdown]
# Create a dictionary for pentamers

# %%
raw_pentamers = {}
for key1, value1 in tetramers.items():
  for key2, value2 in blocks.items():
    new_key = str(int(key1)+int(key2))
    new_value = value1+value2-water
    raw_pentamers[new_key] = new_value

print(raw_pentamers)
print(len(raw_pentamers))

pentamers = {}
for key, value in raw_pentamers.items():
  if value not in pentamers.values():
    pentamers[key] = value

print(pentamers)
print(len(pentamers))
# Out:
# {'500': 5128, '510': 5170, '501': 5086, '511': 5128, '520': 5212, '521': 5170, '502': 5044, '512': 5086, '530': 5254, '531': 5212, '503': 5002, '513': 5044, '540': 5296, '541': 5254, '504': 4960, '514': 5002, '550': 5338, '551': 5296, '505': 4918, '515': 4960}
# 20
# {'500': 5128, '510': 5170, '501': 5086, '520': 5212, '502': 5044, '530': 5254, '503': 5002, '540': 5296, '504': 4960, '550': 5338, '505': 4918}
# 11

# %% [markdown]
# Combine monomers, dimers, trimers, tetramers and pentamers as raw final A result

# %%
raw_finalA = {}
raw_finalA.update(monomers)
raw_finalA.update(dimers)
raw_finalA.update(trimers)
raw_finalA.update(tetramers)
raw_finalA.update(pentamers)

print(raw_finalA)
print(len(raw_finalA))
# Out:
# {'100': 1040, '110': 1082, '101': 998, '200': 2062, '210': 2104, '201': 2020, '220': 2146, '202': 1978, '300': 3084, '310': 3126, '301': 3042, '320': 3168, '302': 3000, '330': 3210, '303': 2958, '400': 4106, '410': 4148, '401': 4064, '420': 4190, '402': 4022, '430': 4232, '403': 3980, '440': 4274, '404': 3938, '500': 5128, '510': 5170, '501': 5086, '520': 5212, '502': 5044, '530': 5254, '503': 5002, '540': 5296, '504': 4960, '550': 5338, '505': 4918}
# 35

# %% [markdown]
# Account for removing (R) alanine bridge for the first monomer
#
# 'R' for removed, 'N' for not removed

# %%
raw_finalB = {}
for key, value in raw_finalA.items():
  new_key_N = key + 'N'
  new_value_N = value
  raw_finalB[new_key_N] = new_value_N
  new_key_R = key + 'R'
  new_value_R = value-ala_bridge+water
  raw_finalB[new_key_R] = new_value_R

print(raw_finalB)
print(len(raw_finalB))
# Out:
# {'100N': 1040, '100R': 898, '110N': 1082, '110R': 940, '101N': 998, '101R': 856, '200N': 2062, '200R': 1920, '210N': 2104, '210R': 1962, '201N': 2020, '201R': 1878, '220N': 2146, '220R': 2004, '202N': 1978, '202R': 1836, '300N': 3084, '300R': 2942, '310N': 3126, '310R': 2984, '301N': 3042, '301R': 2900, '320N': 3168, '320R': 3026, '302N': 3000, '302R': 2858, '330N': 3210, '330R': 3068, '303N': 2958, '303R': 2816, '400N': 4106, '400R': 3964, '410N': 4148, '410R': 4006, '401N': 4064, '401R': 3922, '420N': 4190, '420R': 4048, '402N': 4022, '402R': 3880, '430N': 4232, '430R': 4090, '403N': 3980, '403R': 3838, '440N': 4274, '440R': 4132, '404N': 3938, '404R': 3796, '500N': 5128, '500R': 4986, '510N': 5170, '510R': 5028, '501N': 5086, '501R': 4944, '520N': 5212, '520R': 5070, '502N': 5044, '502R': 4902, '530N': 5254, '530R': 5112, '503N': 5002, '503R': 4860, '540N': 5296, '540R': 5154, '504N': 4960, '504R': 4818, '550N': 5338, '550R': 5196, '505N': 4918, '505R': 4776}
# 70

# %% [markdown]
# Account for adding(+), removing(-) amino acids for the last monomer
#
# '+' for 5 aa, '0‘ for 4 aa, '-' for 3 aa

# %%
final = {}
for key, value in raw_finalB.items():
  new_key_0 = key + '0'
  new_value_0 = value
  final[new_key_0] = new_value_0
  new_key_P = key + '+'
  new_value_P = value+alanine-water
  final[new_key_P] = new_value_P
  new_key_M = key + '-'
  new_value_M = value-alanine+water
  final[new_key_M] = new_value_M

print(final)
print(len(final))
# Out:
# {'100N0': 1040, '100N+': 1111, '100N-': 969, '100R0': 898, '100R+': 969, '100R-': 827, '110N0': 1082, '110N+': 1153, '110N-': 1011, '110R0': 940, '110R+': 1011, '110R-': 869, '101N0': 998, '101N+': 1069, '101N-': 927, '101R0': 856, '101R+': 927, '101R-': 785, '200N0': 2062, '200N+': 2133, '200N-': 1991, '200R0': 1920, '200R+': 1991, '200R-': 1849, '210N0': 2104, '210N+': 2175, '210N-': 2033, '210R0': 1962, '210R+': 2033, '210R-': 1891, '201N0': 2020, '201N+': 2091, '201N-': 1949, '201R0': 1878, '201R+': 1949, '201R-': 1807, '220N0': 2146, '220N+': 2217, '220N-': 2075, '220R0': 2004, '220R+': 2075, '220R-': 1933, '202N0': 1978, '202N+': 2049, '202N-': 1907, '202R0': 1836, '202R+': 1907, '202R-': 1765, '300N0': 3084, '300N+': 3155, '300N-': 3013, '300R0': 2942, '300R+': 3013, '300R-': 2871, '310N0': 3126, '310N+': 3197, '310N-': 3055, '310R0': 2984, '310R+': 3055, '310R-': 2913, '301N0': 3042, '301N+': 3113, '301N-': 2971, '301R0': 2900, '301R+': 2971, '301R-': 2829, '320N0': 3168, '320N+': 3239, '320N-': 3097, '320R0': 3026, '320R+': 3097, '320R-': 2955, '302N0': 3000, '302N+': 3071, '302N-': 2929, '302R0': 2858, '302R+': 2929, '302R-': 2787, '330N0': 3210, '330N+': 3281, '330N-': 3139, '330R0': 3068, '330R+': 3139, '330R-': 2997, '303N0': 2958, '303N+': 3029, '303N-': 2887, '303R0': 2816, '303R+': 2887, '303R-': 2745, '400N0': 4106, '400N+': 4177, '400N-': 4035, '400R0': 3964, '400R+': 4035, '400R-': 3893, '410N0': 4148, '410N+': 4219, '410N-': 4077, '410R0': 4006, '410R+': 4077, '410R-': 3935, '401N0': 4064, '401N+': 4135, '401N-': 3993, '401R0': 3922, '401R+': 3993, '401R-': 3851, '420N0': 4190, '420N+': 4261, '420N-': 4119, '420R0': 4048, '420R+': 4119, '420R-': 3977, '402N0': 4022, '402N+': 4093, '402N-': 3951, '402R0': 3880, '402R+': 3951, '402R-': 3809, '430N0': 4232, '430N+': 4303, '430N-': 4161, '430R0': 4090, '430R+': 4161, '430R-': 4019, '403N0': 3980, '403N+': 4051, '403N-': 3909, '403R0': 3838, '403R+': 3909, '403R-': 3767, '440N0': 4274, '440N+': 4345, '440N-': 4203, '440R0': 4132, '440R+': 4203, '440R-': 4061, '404N0': 3938, '404N+': 4009, '404N-': 3867, '404R0': 3796, '404R+': 3867, '404R-': 3725, '500N0': 5128, '500N+': 5199, '500N-': 5057, '500R0': 4986, '500R+': 5057, '500R-': 4915, '510N0': 5170, '510N+': 5241, '510N-': 5099, '510R0': 5028, '510R+': 5099, '510R-': 4957, '501N0': 5086, '501N+': 5157, '501N-': 5015, '501R0': 4944, '501R+': 5015, '501R-': 4873, '520N0': 5212, '520N+': 5283, '520N-': 5141, '520R0': 5070, '520R+': 5141, '520R-': 4999, '502N0': 5044, '502N+': 5115, '502N-': 4973, '502R0': 4902, '502R+': 4973, '502R-': 4831, '530N0': 5254, '530N+': 5325, '530N-': 5183, '530R0': 5112, '530R+': 5183, '530R-': 5041, '503N0': 5002, '503N+': 5073, '503N-': 4931, '503R0': 4860, '503R+': 4931, '503R-': 4789, '540N0': 5296, '540N+': 5367, '540N-': 5225, '540R0': 5154, '540R+': 5225, '540R-': 5083, '504N0': 4960, '504N+': 5031, '504N-': 4889, '504R0': 4818, '504R+': 4889, '504R-': 4747, '550N0': 5338, '550N+': 5409, '550N-': 5267, '550R0': 5196, '550R+': 5267, '550R-': 5125, '505N0': 4918, '505N+': 4989, '505N-': 4847, '505R0': 4776, '505R+': 4847, '505R-': 4705}
# 210

# %% [markdown]
# Output the final list as a CSV file

# %%
import csv
with open('list.csv', 'w') as f:
  f.write("Index, Property, Molecular weight\n")
  i = 1
  for key in final.keys():
    f.write("%d,%s,%s\n"%(i, key, final[key]))
    i = i+1

# %% [markdown]
# Download the output file from Google Colab workspace

# %%
# !ls
from google.colab import files
files.download('list.csv')
# Out:
# list.csv  sample_data
